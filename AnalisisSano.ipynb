# %% [markdown]
# # Creación de las redes de Tejido Sano usando NetworkX

# %% [markdown]
# Se cargan las librerias que se van a ocupar

# %%
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
import networkx.algorithms.community as nx_comm
import numpy as np
from ipywidgets import *
import math as math

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## Para Tejido sano sin normalizar
#
# # TCGA

# %%
#Lectura del archivo de la red a analizar
file = open("TejidoSanoRecortada.txt")

#G=nx.read_weighted_edgelist(file,create_using=nx.Graph(),nodetype=str)
G=nx.read_weighted_edgelist(file)

# %%
#Impresión de la red que se pretende analizar. en 2D
anch = 30
alt = anch/float(1.6180334)
fig, ax = plt.subplots(figsize=(anch, alt))
nx.draw(G,node_size = 10, width = 0.3,)
plt.show()

plt.savefig("Ejemplo1.jpg")
dgenes = dict(nx.degree(G))

# %%
# 3d spring layout
#pos = nx.spring_layout(G, dim=3, seed=779)
# Extract node and edge positions from the layout
#node_xyz = np.array([pos[v] for v in sorted(G)])
#edge_xyz = np.array([(pos[u], pos[v]) for u, v in G.edges()])

# Create the 3D figure
#fig = plt.figure()
#ax = fig.add_subplot(111, projection="3d")

# Plot the nodes - alpha is scaled by "depth" automatically
#ax.scatter(*node_xyz.T, s=100, ec="w")

# Plot the edges
#for vizedge in edge_xyz:
#    ax.plot(*vizedge.T, color="tab:gray")


#def _format_axes(ax):
#    """Visualization options for the 3D axes."""
    # Turn gridlines off
#    ax.grid(False)
    # Suppress tick labels
#    for dim in (ax.xaxis, ax.yaxis, ax.zaxis):
#        dim.set_ticks([])
    # Set axes labels
#    ax.set_xlabel("x")
#    ax.set_ylabel("y")
#    ax.set_zlabel("z")


#_format_axes(ax)
#fig.tight_layout()
#plt.savefig("Figura Red3D.jpg")
#plt.show()

# %%
#Ordenamiento de los valores
seqgenes = sorted(dgenes.values())

#Obtención de los parametros K, C y L de la red analizada
k = sum(dgenes.values()) / len(dgenes)    
C = nx.average_clustering(G)
#L = nx.average_path_length(G)

print("Grado promedio de los nodos: ", k)
print("Centralidad promedio de los nodos: ",C)
#print("Diámetro de la red: ", L)
# Out:
# Grado promedio de los nodos:  474.71087166735737
# Centralidad promedio de los nodos:  0.5337342066752715

# %%
anch = 30
alt = anch/float(1.6180334)
p = sns.histplot(seqgenes,stat='count',kde=True, fill= True, element='step',label='$< k > =$ %f \n $< C > =$ %f \n' % (k,C))
p.set(xlim = (0,2000), xlabel = "$k$", ylabel = "$P(k)$",title='Distribucion de grado modelo de la red de genes de tejido sano')
# Out:
# [(0.0, 2000.0),
#  Text(0.5, 0, '$k$'),
#  Text(0, 0.5, '$P(k)$'),
#  Text(0.5, 1.0, 'Distribucion de grado modelo de la red de genes de tejido sano')]

# %% [markdown]
# ## Para Tejido Sano Normalizado
#
# # log^2

# %%
#Lectura del archivo de la red a analizar
file = open("SortSanoRecortadaNORM.txt")

#G=nx.read_weighted_edgelist(file,create_using=nx.Graph(),nodetype=str)
G=nx.read_weighted_edgelist(file)

#read_edgelist(file,create_using=nx.Graph(),nodetype=str)
pos = nx.spring_layout(G,iterations = 70)

# %%
#Impresión de la red que se pretende analizar. en 2D
anch = 30
alt = anch/float(1.6180334)
fig, ax = plt.subplots(figsize=(anch, alt))
nx.draw(G,node_size = 10, width = 0.3,)
plt.show()

plt.savefig("Ejemplo1.jpg")
dgenes = dict(nx.degree(G))

# %%
#Ordenamiento de los valores
seqgenes = sorted(dgenes.values())

#Obtención de los parametros K, C y L de la red analizada
k = sum(dgenes.values()) / len(dgenes)    
C = nx.average_clustering(G)
#L = nx.average_path_length(G)

print("Grado promedio de los nodos: ", k)
print("Centralidad promedio de los nodos: ",C)
#print("Diámetro de la red: ", L)
# Out:
# Grado promedio de los nodos:  455.8547335886582
# Centralidad promedio de los nodos:  0.5373193734835169

# %%
anch = 30
alt = anch/float(1.6180334)
p = sns.histplot(seqgenes,stat='count',kde=True, fill= True, element='step',label='$< k > =$ %f \n $< C > =$ %f \n' % (k,C))
p.set(xlim = (0,2000), xlabel = "$k$", ylabel = "$P(k)$",title='Distribucion de grado modelo de la red de genes de Tejido sano')
# Out:
# [(0.0, 2000.0),
#  Text(0.5, 0, '$k$'),
#  Text(0, 0.5, '$P(k)$'),
#  Text(0.5, 1.0, 'Distribucion de grado modelo de la red de genes de Tejido sano')]

# %% [markdown]
# ## Para Tejido Sano Normalizado
#
# # 1/log2

# %%
#Lectura del archivo de la red a analizar
file = open("Norm1Recortada.txt")

#G=nx.read_weighted_edgelist(file,create_using=nx.Graph(),nodetype=str)
G=nx.read_weighted_edgelist(file)

#read_edgelist(file,create_using=nx.Graph(),nodetype=str)
pos = nx.spring_layout(G,iterations = 70)

# %%
#Impresión de la red que se pretende analizar. en 2D
anch = 30
alt = anch/float(1.6180334)
fig, ax = plt.subplots(figsize=(anch, alt))
nx.draw(G,node_size = 10, width = 0.3,)
plt.show()

plt.savefig("Ejemplo1.jpg")
dgenes = dict(nx.degree(G))

# %%
#Ordenamiento de los valores mnn7
seqgenes = sorted(dgenes.values())

#Obtención de los parametros K, C y L de la red analizada
k = sum(dgenes.values()) / len(dgenes)    
C = nx.average_clustering(G)
#L = nx.average_path_length(G)

print("Grado promedio de los nodos: ", k)
print("Centralidad promedio de los nodos: ",C)
#print("Diámetro de la red: ", L)
# Out:
# Grado promedio de los nodos:  461.91903389597917
# Centralidad promedio de los nodos:  0.5377588042173091

# %%
anch = 30
alt = anch/float(1.6180334)
p = sns.histplot(seqgenes,stat='count',kde=True, fill= True, element='step',label='$< k > =$ %f \n $< C > =$ %f \n' % (k,C))
p.set(xlim = (0,2000), xlabel = "$k$", ylabel = "$P(k)$",title='Distribucion de grado modelo de la red de genes de Tejido sano con valores normalizados 1/log2')
# Out:
# [(0.0, 2000.0),
#  Text(0.5, 0, '$k$'),
#  Text(0, 0.5, '$P(k)$'),
#  Text(0.5, 1.0, 'Distribucion de grado modelo de la red de genes de Tejido sano con valores normalizados 1/log2')]
