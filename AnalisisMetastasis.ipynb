# %% [markdown]
# # Creación de las redes de Tejido con metastasis usando NetworkX

# %% [markdown]
# Se cargan las librerias que se van a ocupar

# %%
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
import networkx.algorithms.community as nx_comm
import numpy as np
from ipywidgets import *
import math as math

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# # Ilumina
#
# ## Umbral >= 0.4

# %%
#Lectura del archivo de la red a analizar
file = open("0.4.txt")

#G=nx.read_weighted_edgelist(file,create_using=nx.Graph(),nodetype=str)
G=nx.read_weighted_edgelist(file)

# %%
#Impresión de la red que se pretende analizar. en 2D
anch = 30
alt = anch/float(1.6180334)
fig, ax = plt.subplots(figsize=(anch, alt))
nx.draw(G,node_size = 10, width = 0.3,)
plt.show()

plt.savefig("metastasis04.jpg")
dgenes = dict(nx.degree(G))

# %%
# 3d spring layout
#pos = nx.spring_layout(G, dim=3, seed=779)
# Extract node and edge positions from the layout
#node_xyz = np.array([pos[v] for v in sorted(G)])
#edge_xyz = np.array([(pos[u], pos[v]) for u, v in G.edges()])

# Create the 3D figure
#fig = plt.figure()
#ax = fig.add_subplot(111, projection="3d")

# Plot the nodes - alpha is scaled by "depth" automatically
#ax.scatter(*node_xyz.T, s=100, ec="w")

# Plot the edges
#for vizedge in edge_xyz:
#    ax.plot(*vizedge.T, color="tab:gray")


#def _format_axes(ax):
#    """Visualization options for the 3D axes."""
    # Turn gridlines off
#    ax.grid(False)
    # Suppress tick labels
#    for dim in (ax.xaxis, ax.yaxis, ax.zaxis):
#        dim.set_ticks([])
    # Set axes labels
#    ax.set_xlabel("x")
#    ax.set_ylabel("y")
#    ax.set_zlabel("z")


#_format_axes(ax)
#fig.tight_layout()
#plt.savefig("Figura Red3D.jpg")
#plt.show()

# %%
#Ordenamiento de los valores
seqgenes = sorted(dgenes.values())

#Obtención de los parametros K, C y L de la red analizada
k = sum(dgenes.values()) / len(dgenes)    
C = nx.average_clustering(G)
#L = nx.average_path_length(G)

print("Grado promedio de los nodos: ", k)
print("Centralidad promedio de los nodos: ",C)
#print("Diámetro de la red: ", L)
# Out:
# Grado promedio de los nodos:  61.050941648656995
# Centralidad promedio de los nodos:  0.5285013696816669

# %%
anch = 30
alt = anch/float(1.6180334)
p = sns.histplot(seqgenes,stat='count',kde=True, fill= True, element='step',label='$< k > =$ %f \n $< C > =$ %f \n' % (k,C))
p.set(xlim = (0,1000), xlabel = "$k$", ylabel = "$P(k)$",title='Distribucion de grado modelo de la red de genes de primera metástasis de cancer de mama en nodos linfativos')
# Out:
# [(0.0, 1000.0),
#  Text(0.5, 0, '$k$'),
#  Text(0, 0.5, '$P(k)$'),
#  Text(0.5, 1.0, 'Distribucion de grado modelo de la red de genes de primera metástasis de cancer de mama en nodos linfativos')]

# %% [markdown]
# ## Umbral >= 0.35

# %%
#Lectura del archivo de la red a analizar
file = open("0.35.txt")

#G=nx.read_weighted_edgelist(file,create_using=nx.Graph(),nodetype=str)
G=nx.read_weighted_edgelist(file)

# %%
#Impresión de la red que se pretende analizar. en 2D
anch = 30
alt = anch/float(1.6180334)
fig, ax = plt.subplots(figsize=(anch, alt))
nx.draw(G,node_size = 10, width = 0.3,)
plt.show()

plt.savefig("metastasis035.jpg")
dgenes = dict(nx.degree(G))

# %%
#Ordenamiento de los valores
seqgenes = sorted(dgenes.values())

#Obtención de los parametros K, C y L de la red analizada
k = sum(dgenes.values()) / len(dgenes)    
C = nx.average_clustering(G)
#L = nx.average_path_length(G)

print("Grado promedio de los nodos: ", k)
print("Centralidad promedio de los nodos: ",C)
#print("Diámetro de la red: ", L)
# Out:
# Grado promedio de los nodos:  222.84134615384616
# Centralidad promedio de los nodos:  0.61409325835201

# %%
anch = 30
alt = anch/float(1.6180334)
p = sns.histplot(seqgenes,stat='count',kde=True, fill= True, element='step',label='$< k > =$ %f \n $< C > =$ %f \n' % (k,C))
p.set(xlim = (0,1000), xlabel = "$k$", ylabel = "$P(k)$",title='Distribucion de grado modelo de la red de genes de primera metástasis de cancer de mama en nodos linfativos')
# Out:
# [(0.0, 1000.0),
#  Text(0.5, 0, '$k$'),
#  Text(0, 0.5, '$P(k)$'),
#  Text(0.5, 1.0, 'Distribucion de grado modelo de la red de genes de primera metástasis de cancer de mama en nodos linfativos')]

# %% [markdown]
# # Ilumina
#
# ## Umbral >= 0.325

# %%
#Lectura del archivo de la red a analizar
file = open("0.325.txt")

#G=nx.read_weighted_edgelist(file,create_using=nx.Graph(),nodetype=str)
G=nx.read_weighted_edgelist(file)

# %%
#Impresión de la red que se pretende analizar. en 2D
anch = 30
alt = anch/float(1.6180334)
fig, ax = plt.subplots(figsize=(anch, alt))
nx.draw(G,node_size = 10, width = 0.3,)
plt.show()

plt.savefig("metastasis0.25.jpg")
dgenes = dict(nx.degree(G))

# %%
#Ordenamiento de los valores
seqgenes = sorted(dgenes.values())

#Obtención de los parametros K, C y L de la red analizada
k = sum(dgenes.values()) / len(dgenes)    
C = nx.average_clustering(G)
#L = nx.average_path_length(G)

print("Grado promedio de los nodos: ", k)
print("Centralidad promedio de los nodos: ",C)
#print("Diámetro de la red: ", L)
# Out:
# Grado promedio de los nodos:  374.54918655922154
# Centralidad promedio de los nodos:  0.6515707018187266

# %%
anch = 30
alt = anch/float(1.6180334)
p = sns.histplot(seqgenes,stat='count',kde=True, fill= True, element='step',label='$< k > =$ %f \n $< C > =$ %f \n' % (k,C))
p.set(xlim = (0,1500), xlabel = "$k$", ylabel = "$P(k)$",title='Distribucion de grado modelo de la red de genes de primera metástasis de cancer de mama en nodos linfativos')
# Out:
# [(0.0, 1500.0),
#  Text(0.5, 0, '$k$'),
#  Text(0, 0.5, '$P(k)$'),
#  Text(0.5, 1.0, 'Distribucion de grado modelo de la red de genes de primera metástasis de cancer de mama en nodos linfativos')]

# %% [markdown]
# # Ilumina
#
# ## Umbral >= 0.3

# %%
#Lectura del archivo de la red a analizar
file = open("0.3.txt")

#G=nx.read_weighted_edgelist(file,create_using=nx.Graph(),nodetype=str)
G=nx.read_weighted_edgelist(file)

# %%
#Impresión de la red que se pretende analizar. en 2D
anch = 30
alt = anch/float(1.6180334)
fig, ax = plt.subplots(figsize=(anch, alt))
nx.draw(G,node_size = 10, width = 0.3,)
plt.show()

plt.savefig("metastasis03.jpg")
dgenes = dict(nx.degree(G))

# %%
#Ordenamiento de los valores
seqgenes = sorted(dgenes.values())

#Obtención de los parametros K, C y L de la red analizada
k = sum(dgenes.values()) / len(dgenes)    
C = nx.average_clustering(G)
#L = nx.average_path_length(G)

print("Grado promedio de los nodos: ", k)
print("Centralidad promedio de los nodos: ",C)
#print("Diámetro de la red: ", L)
# Out:
# Grado promedio de los nodos:  584.9417028892866
# Centralidad promedio de los nodos:  0.6795867561206115

# %%
anch = 30
alt = anch/float(1.6180334)
p = sns.histplot(seqgenes,stat='count',kde=True, fill= True, element='step',label='$< k > =$ %f \n $< C > =$ %f \n' % (k,C))
p.set(xlim = (0,2000), xlabel = "$k$", ylabel = "$P(k)$",title='Distribucion de grado modelo de la red de genes de primera metástasis de cancer de mama en nodos linfativos')
# Out:
# [(0.0, 2000.0),
#  Text(0.5, 0, '$k$'),
#  Text(0, 0.5, '$P(k)$'),
#  Text(0.5, 1.0, 'Distribucion de grado modelo de la red de genes de primera metástasis de cancer de mama en nodos linfativos')]
